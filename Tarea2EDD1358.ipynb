# %% [markdown]
# <a href="https://colab.research.google.com/github/4skura/EDD_1358_2021/blob/master/Tarea2EDD1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Array
"""
class Array:
  def __init__(self, tam):
    #generador de datos, llena el arreglo con ceros
    self.__datos = [0 for x in range(tam)] 

  def get_item(self, index):
    dato = 0
    if index >= 0 and index < len(self.__datos):
      dato= self.__datos[index]
    else:
      print("Error en el indice")
    return dato

  def set_item(self, dato, index):
    if index >= 0 and index < len(self.__datos):
      self.__datos[index]= dato
    else:
      print("Error en el indice")
    return dato
  
  def get_length(self):
    #Obtener el tamaño del arreglo
    return len(self.__datos)
  
  def clear(self, dato):
    self.__datos = [dato for x in range(self.__tam)]

  def __iter__(self):
    return _getIterator(self.__datos)

#iterador
class _getIterator:
  def __init__(self, arreglo):
    self.__arreglo= arreglo
    self.__indice_actual=0

  def __iter__(self):
    return self

  def __next__(self):
    if self.__indice_actual < len(self.__arreglo):
      dato= self.__arreglo[self.__indice_actual]
      self.__indice_actual +=1
      return dato
    else:
      raise StopIteration
  
  def getIterator(self):
    return _getIterator(self.__datos)

# %%
class empleado:
  def __init__(self, num, nom, pat, mat, he, sb, anio):
    self.__num_trabajador= num
    self.__nombres= nom
    self.__apellido_paterno= pat
    self.__apellido_materno= mat
    self.__horas_extra= he
    self.__salario_base= sb
    self.__anio_ingreso= anio

  #get y set
  def get_num_Trabajador(self):
    return self.__num_trabajador

  def set_num_Trabajador(self, num):
    self.__num_trabajador= num
    return num
  
  def get_nombres(self):
    return self.__nombres

  def set_nombres(self, nom):
    self.__nombres= nom
    return nom

  def get_apellido_paterno(self):
    return self.__apellido_paterno

  def set_apellido_paterno(self, pat):
    self.__apellido_paterno= pat
    return pat

  def get_apellido_materno(self):
    return self.__apellido_materno

  def set_apellido_materno(self, mat):
    self.__apellido_materno= mat
    return mat

  def get_horas_extra(self):
    return self.__horas_extra

  def set_horas_extra(self, he):
    self.__horas_extra=he
    return he

  def get_salario_base(self):
    return self.__salario_base

  def set_salario_base(self, sb):
    self.__salario_base=sb
    return sb

  def get_anio_ingreso(self):
    return self.__anio_ingreso

  def set_anio_ingreso(self, anio):
    self.get_anio_ingreso=__anio_ingreso
    return anio

  #def sueldo(self, sb, he):
  #metodos de uso general: calculos
  #to string
  def to_String(self):
    str1=''
    return str1

# %%
"""
Cargar datos
ADT sueldos
"""
#un ADT encapsula los datos
#cargar_datos(ruta_archivo)
#calcular_sueldo()
#reportar_mayor_antiguedad
#reportar_menor_antiguedad()

class Sueldos:
  def __init__(self):
    self.__data= None

  def cargar_datos(self, ruta_archivo):
    archivo= open(ruta_archivo, 'rt', encoding='latin1')
    cabeceras=archivo.readline()
    lineas= archivo.readlines()
    archivo.close()
    self.__data=Array( len(lineas) -1)
    #tarea
    numeros_trabajadores= []
    #separar campos y hacer casting
    for linea in lineas:
      linea=linea.split(',')
      linea[0]=int(linea[0])
      linea[4]=int(linea[4])
      linea[5]=int(linea[5])
      anio=linea[6]
      anio=int(anio)
      linea[6]=anio
      #print(linea)
      #print(linea[0])
      
      numeros_trabajadores.append(linea[0])
      
      #print(numeros_trabajadores)
      #crear un objeto
      trabajador=empleado(linea[0],linea[1],linea[2],linea[3],linea[4],linea[5],linea[6])
      salario_final=0
      antiguedad=0
      antiguedad=2020-(trabajador.get_anio_ingreso())
      if antiguedad ==0:
        salario_final=(trabajador.get_salario_base()+(trabajador.get_horas_extra() *276.5))
      else:
        salario_final=(trabajador.get_salario_base()+(trabajador.get_horas_extra() *276.5))+(trabajador.get_salario_base()*0.03*antiguedad)
      print(f"El salario final de {trabajador.get_nombres()} {trabajador.get_apellido_paterno()} es de {salario_final}")
    
      #subir el objeto al arreglo con self.__data.set_item()

    print("")
    for linea in lineas:
      linea=linea.split(',')
      anio=linea[6]
      anio=int(anio)
      linea[6]=anio
      #menor antiguedad
      if anio ==2020:
        menor_antiguedad= []
        menor_antiguedad.append(linea[1])
        menor_antiguedad.append(linea[2])
        menor_antiguedad.append(linea[3])
        print(f"El empleado con menor antiguedad es {menor_antiguedad[0]} {menor_antiguedad[1]} {menor_antiguedad[2]}")
    
    print("")
    for linea in lineas:
      linea=linea.split(',')
      anio=linea[6]
      anio=int(anio)
      linea[6]=anio
      if anio==2016:
        mayor_antiguedad= []
        mayor_antiguedad.append(linea[1])
        mayor_antiguedad.append(linea[2])
        mayor_antiguedad.append(linea[3])
        print(f"El empleado con mayor antiguedad es {mayor_antiguedad[0]} {mayor_antiguedad[1]} {mayor_antiguedad[2]}")

ejemplo= Sueldos()
ejemplo.cargar_datos('junio.dat')
# Out:
# El salario final de CARLOS PEREZ es de 10736.5
# El salario final de ANGEL GOMEZ es de 10126.5
# El salario final de JESUS MARTIN es de 11585.0
# El salario final de DAVID JIMENEZ es de 11289.5
# El salario final de PEDRO RUIZ es de 11289.5
# El salario final de DANIEL HERNANDEZ es de 11270.5
# El salario final de ALEJANDRO DIAZ es de 10994.0
# El salario final de MARIA MORENO es de 10717.5
# El salario final de ALBERTO MUOZ es de 11013.0
# El salario final de RAFAEL ALVAREZ es de 11289.5
# El salario final de FERNANDO ROMERO es de 11251.5
# El salario final de PABLO ALONSO es de 10422.0
# El salario final de JORGE GUTIERREZ es de 10403.0
# El salario final de RAMON NAVARRO es de 11308.5
#
# El empleado con menor antiguedad es ANGEL GOMEZ GARRIDO
# El empleado con menor antiguedad es JORGE GUTIERREZ MARQUEZ
#
# El empleado con mayor antiguedad es JESUS MARTIN SANTOS
# El empleado con mayor antiguedad es RAMON NAVARRO LEON
