# %% [markdown]
# <a href="https://colab.research.google.com/github/4skura/EDD_1358_2021/blob/master/Tarea9EDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Queue:
  def __init__(self):
    self.__data= list()

  def is_empty(self):
    return len(self.__data)== 0

  def lenght(self):
    return len(self.__data)

  def enqueue(self, item):
    self.__data.append(item)

  def dequeue(self):
    if not self.is_empty():
      return self.__data.pop(0)
    else:
      return None

  def to_string(self):
    cadena = ""
    for elem in self.__data:
      cadena = cadena + " | " + elem  
    cadena = cadena + " | "
    return cadena

# %%
class BoundedPriorityQueue:
  def __init__( self , niveles ):
    self.__data = [ Queue() for x in range(niveles) ]
    self.__size = 0

  def is_empty( self ):
    return self.__size == 0
    
  def length( self ):
    return self.__size
    
  def enqueue( self , prioridad , elem ):
    if prioridad < len(self.__data) and prioridad >= 0:
        self.__data[prioridad].enqueue(elem)
        self.__size +=1
    else:
        print(f"El elemento {elem} esta fuera de rango.")
    
  def dequeue( self ):
    nivel = 0
    if not self.is_empty():
      while self.__data[nivel].is_empty() and(self.__size > 0):
        nivel += 1
      self.__size -=1
    return self.__data[nivel].dequeue()


  def dequeueAutomatico(self):
    while not self.is_empty():
      print("")
      self.dequeue()
      self.to_string()
    print("\nFin de la cola, el barco esta vacio")
    
  def to_string( self ):
    for nivel in range( len(self.__data) ):
      print(f" Nivel { nivel } --> { self.__data[nivel].to_string() } ")

# %%
barco = BoundedPriorityQueue(6)
barco.enqueue(4,'Maestre')
barco.enqueue(2,'Niños')
barco.enqueue(4,'Mecánico')
barco.enqueue(3,'Hombres')
barco.enqueue(4,'Vigia')
barco.enqueue(5,'Capitán')
barco.enqueue(4,'Timonel')
barco.enqueue(3,'Mujeres')
barco.enqueue(2,'3ra edad')
barco.enqueue(1,'Niñas')
barco.to_string()
barco.dequeueAutomatico()
# Out:
#  Nivel 0 -->  |
#  Nivel 1 -->  | Niñas |
#  Nivel 2 -->  | Niños | 3ra edad |
#  Nivel 3 -->  | Hombres | Mujeres |
#  Nivel 4 -->  | Maestre | Mecánico | Vigia | Timonel |
#  Nivel 5 -->  | Capitán |
#
#  Nivel 0 -->  |
#  Nivel 1 -->  |
#  Nivel 2 -->  | Niños | 3ra edad |
#  Nivel 3 -->  | Hombres | Mujeres |
#  Nivel 4 -->  | Maestre | Mecánico | Vigia | Timonel |
#  Nivel 5 -->  | Capitán |
#
#  Nivel 0 -->  |
#  Nivel 1 -->  |
#  Nivel 2 -->  | 3ra edad |
#  Nivel 3 -->  | Hombres | Mujeres |
#  Nivel 4 -->  | Maestre | Mecánico | Vigia | Timonel |
#  Nivel 5 -->  | Capitán |
#
#  Nivel 0 -->  |
#  Nivel 1 -->  |
#  Nivel 2 -->  |
#  Nivel 3 -->  | Hombres | Mujeres |
#  Nivel 4 -->  | Maestre | Mecánico | Vigia | Timonel |
#  Nivel 5 -->  | Capitán |
#
#  Nivel 0 -->  |
#  Nivel 1 -->  |
#  Nivel 2 -->  |
#  Nivel 3 -->  | Mujeres |
#  Nivel 4 -->  | Maestre | Mecánico | Vigia | Timonel |
#  Nivel 5 -->  | Capitán |
#
#  Nivel 0 -->  |
#  Nivel 1 -->  |
#  Nivel 2 -->  |
#  Nivel 3 -->  |
#  Nivel 4 -->  | Maestre | Mecánico | Vigia | Timonel |
#  Nivel 5 -->  | Capitán |
#
#  Nivel 0 -->  |
#  Nivel 1 -->  |
#  Nivel 2 -->  |
#  Nivel 3 -->  |
#  Nivel 4 -->  | Mecánico | Vigia | Timonel |
#  Nivel 5 -->  | Capitán |
#
#  Nivel 0 -->  |
#  Nivel 1 -->  |
#  Nivel 2 -->  |
#  Nivel 3 -->  |
#  Nivel 4 -->  | Vigia | Timonel |
#  Nivel 5 -->  | Capitán |
#
#  Nivel 0 -->  |
#  Nivel 1 -->  |
#  Nivel 2 -->  |
#  Nivel 3 -->  |
#  Nivel 4 -->  | Timonel |
#  Nivel 5 -->  | Capitán |
#
#  Nivel 0 -->  |
#  Nivel 1 -->  |
#  Nivel 2 -->  |
#  Nivel 3 -->  |
#  Nivel 4 -->  |
#  Nivel 5 -->  | Capitán |
#
#  Nivel 0 -->  |
#  Nivel 1 -->  |
#  Nivel 2 -->  |
#  Nivel 3 -->  |
#  Nivel 4 -->  |
#  Nivel 5 -->  |
#
# Fin de la cola, el barco esta vacio
