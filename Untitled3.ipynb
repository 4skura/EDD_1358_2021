# %% [markdown]
# <a href="https://colab.research.google.com/github/4skura/EDD_1358_2021/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Array2D: #Clase Array2D
	def __init__(self,ren,col):
		self.__fila = ren
		self.__columna = col
		self.arreglo =[ [0 for i in range(col)] for i in range(ren)]

	
	def get_row_size(self):
		return self.__fila
	def get_col_size(self):
		return self.__columna
	def set_item(self,ren,col,dato):
		self.arreglo[ren][col] = dato
	def get_item(self,ren,col):
		return self.arreglo[ren][col]
	def to_string(self):
		return self.arreglo


class JuegoDeLaVida:

	def __init__(self,rens,cols,generaciones,poblacion):
		self.largo = cols
		self.alto = rens
		self.grid = Array2D(self.alto,self.largo)
		self.generaciones = generaciones

		for i in poblacion:
			self.grid.set_item(i[0],i[1],1)
		
#grid para la impresion
	def imprime_grid(self):
		for r in range(self.grid.get_col_size()):
			for c in range(self.grid.get_row_size()):
				if self.grid.get_item(r,c) == 0:

					print('░░',end='')
				else:
					print('██',end = '')

			print('')
		print('\n')

	def get_num_rows(self):
		return self.alto
	def get_num_cols(self):
		return self.largo
	def set_celula_muerta(self,row,col):
		self.grid.set_item(row,col,0)	
	def set_celula_viva(self,row,col):
		self.grid.set_item(row,col,1)	

	def get_is_viva(self,row,col):
		return self.grid.get_item(row,col) == 1

	def get_is_muerta(self,row,col):
		return self.grid.get_item(row,col) == 0

	def get_numero_vecinos_vivos(self,row,col): 
		num_vecinos = 0

		for i in [row-1, row , row+1]:
			for j in [col-1, col , col+1]:
				try:
					if self.grid.get_item(i,j) == 1  and (i,j) != (row,col):
						num_vecinos += 1
				except Exception as e:
					pass
					
		return num_vecinos


	def calculo_gen(self): 

		for i in range(self.generaciones):

			array = self.grid.to_string()

			self.imprime_grid()

			lista_proximo_vivos = []
			lista_proximo_muertos = []

			for row in range(self.alto):

				for col in range(self.largo):
					if self.get_numero_vecinos_vivos(row,col) == 3:
						lista_proximo_vivos.append((row,col))

					if self.get_numero_vecinos_vivos(row,col) == 2 :
						pass

					if self.get_numero_vecinos_vivos(row,col) < 2 or self.get_numero_vecinos_vivos(row,col) > 3:
						lista_proximo_muertos.append((row,col))
			
			for i in lista_proximo_vivos:
				self.set_celula_viva(i[0],i[1])

			for i in lista_proximo_muertos:
				self.set_celula_muerta(i[0],i[1])

# %%
semilla=[]
dato= None
print("ingrese las dimensiones del arreglo")
print("Ingrese el numero de filas")
fila=input()
fila= int (fila)
if fila>0:
  print("Ingrese el numero de columnas")
  columna=input()
  columna= int (columna)
  if columna>0:
    print("Ingrese los datos de la poblacion inicial con el formato x,y")
    print("Presione enter para introducir otra celula viva, y al terminar escriba \u0022fin\u0022")
    dato=input()
    semilla.append(dato)
    while (dato != 'fin'):
      print("introduzca el siguiente dato, al terminar escriba \u0022fin\u0022")
      dato=input()
      semilla.append(dato)
      print(semilla)




print("Esta es una semilla de ejemplo\n\n1")
semilla_ejemplo= JuegoDeLaVida(7,7,6,[(1,2),(2,2),(2,1),(2,3)]) 
semilla_ejemplo.calculo_gen()
# Out:
# ingrese las dimensiones del arreglo
# Ingrese el numero de filas
# 10
# Ingrese el numero de columnas
# 10
# Ingrese los datos de la poblacion inicial con el formato x,y
# Presione enter para introducir otra celula viva, y al terminar escriba "fin"
# 1,2
# introduzca el siguiente dato, al terminar escriba "fin"
# 2,1
# ['1,2', '2,1']
# introduzca el siguiente dato, al terminar escriba "fin"
#
# ['1,2', '2,1', '']
# introduzca el siguiente dato, al terminar escriba "fin"
# fin
# ['1,2', '2,1', '', 'fin']
# Esta es una semilla de ejemplo
#
# 1
# ░░░░░░░░░░░░░░
# ░░░░██░░░░░░░░
# ░░██████░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
#
# ░░░░░░░░░░░░░░
# ░░██████░░░░░░
# ░░██████░░░░░░
# ░░░░██░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
#
# ░░░░██░░░░░░░░
# ░░██░░██░░░░░░
# ░░░░░░░░░░░░░░
# ░░██████░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
#
# ░░░░██░░░░░░░░
# ░░░░██░░░░░░░░
# ░░██░░██░░░░░░
# ░░░░██░░░░░░░░
# ░░░░██░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
#
# ░░░░░░░░░░░░░░
# ░░██████░░░░░░
# ░░██░░██░░░░░░
# ░░██████░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
#
# ░░░░██░░░░░░░░
# ░░██░░██░░░░░░
# ██░░░░░░██░░░░
# ░░██░░██░░░░░░
# ░░░░██░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
